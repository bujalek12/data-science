# %%
import pandas as pd
programmers = pd.read_csv("StackOverflowDeveloperSurvey2018.csv",low_memory=False,usecols=['ConvertedSalary']).squeeze().dropna()
programmers.head()
# Out:
# 0                                          Yes
# 1               Taught yourself a new language
# 3                                          Yes
# 4     or tool without taking a formal course""
# 5                                    framework
# Name: ConvertedSalary, dtype: object

# %%
programmers.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 programmers.mean()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# ...

# %%
programmers.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 programmers.median()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:6235, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6227 @doc(make_doc("median", ndim=1))
#    6228 def median(
#    6229     self,
#    (...)
#    6233     **kwargs,
#    6234 ):
# -> 6235     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:12003, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11996 def median(
#   11997     self,
#   11998     axis: Axis | None = 0,
#    (...)
#   12001     **kwargs,
#   12002 ) -> Series | float:
# > 12003     return self._stat_function(
#   12004         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
# ...

# %%
programmers.std()

# %%
programmers.max()

# %%
fortune = pd.read_csv("Fortune_500_2017.csv", usecols=['Employees','Title'],index_col=['Title']).squeeze().dropna()
fortune.head()

# %%
fortune.idxmax()

# %%
fortune.loc[fortune.idxmax()]

# %%
fortune.idxmin()

# %%
fortune.loc[fortune.idxmin()]
